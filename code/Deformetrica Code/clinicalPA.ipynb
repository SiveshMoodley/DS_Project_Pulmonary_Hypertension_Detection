# %%
import os
import glob
import re
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import deformetrica as dfca

# %%
#Visualise the data:
data_path = '/u/i/sm2894/Documents/FYP/Data/'
data_base = os.path.join(data_path, 'primed/DataPA/')

vtk_files = glob.glob(data_base + "*.vtk")

vtk_file =vtk_files[0]
print(vtk_file)
target_points__raw, _, target_connectivity__raw = dfca.io.DeformableObjectReader.read_file(vtk_file, extract_connectivity=True)
print(target_points__raw.shape)
print(target_connectivity__raw.shape)

figsize = 5
f = plt.figure(figsize=(5 * figsize, 1 * figsize))
gs = gridspec.GridSpec(1, len(vtk_files))

for i, vtk_file in enumerate(vtk_files):
    ax = plt.subplot(gs[0, i])
    # color = cmap(i % 10)[:3]

    m = re.findall(r".*\/(.*)\..*", vtk_file)
    target_id = m[0]
    target_points__raw, _, target_connectivity__raw = dfca.io.DeformableObjectReader.read_file(vtk_file, extract_connectivity=True)

    p = target_points__raw
    c = target_connectivity__raw
    ax.plot([p[c[:, 0]][:, 0], p[c[:, 1]][:, 0]],
            [p[c[:, 0]][:, 1], p[c[:, 1]][:, 1]],
            'k', linewidth=2)
    ax.set_title(target_id)

plt.style.use('default')
plt.show()

# %%
import os
import deformetrica as dfca

### EDIT THESE PATHS #####################
data_path = '/u/i/sm2894/Documents/FYP/Data/'
data_base = os.path.join(data_path, 'primed/DataPA/')

output_directory = './clinicalPA_output/' #directory where the outputs will be saved
########################################

iteration_status_dictionaries = []

def estimator_callback(status_dict):
    iteration_status_dictionaries.append(status_dict)
    return True

# instantiate a Deformetrica object
deformetrica = dfca.Deformetrica(output_dir=output_directory, verbosity='INFO')

dataset_specifications = {
    'dataset_filenames': [
        [{'pulmonary artery': os.path.join(data_base, 'Imbio01.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio02.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio03.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio05.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio06.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio07.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio08.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio09.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio10.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio11.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio12.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio15.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio16.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio17.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio18.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio19.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio20.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio21.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio22.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio23.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio24.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio25.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio26.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio29.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio30.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio31.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio32.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio33.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio34.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio36.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio37.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio38.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio39.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio40.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio41.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio43.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio44.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio45.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio46.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio47.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio48.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio49.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio50.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio51.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio52.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio53.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio54.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio55.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio56.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio57.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'Imbio59.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'S01.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'S02.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'S03.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'S04.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'S05.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'S08.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'S09.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'S10.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'S11.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'S12.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'S13.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'S14.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'S15.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'S16.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'S17.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'S18.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'S19.vtk')}],
        [{'pulmonary artery': os.path.join(data_base, 'S20.vtk')}]
    ],
    'subject_ids': [
        'subject1', 'subject2', 'subject3', 'subject4', 'subject5', 'subject6', 'subject7', 'subject8', 'subject9', 'subject10',
        'subject11', 'subject12', 'subject13', 'subject14', 'subject15', 'subject16', 'subject17', 'subject18', 'subject19', 'subject20',
        'subject21', 'subject22', 'subject23', 'subject24', 'subject25', 'subject26', 'subject27', 'subject28', 'subject29', 'subject30',
        'subject31', 'subject32', 'subject33', 'subject34', 'subject35', 'subject36', 'subject37', 'subject38', 'subject39', 'subject40',
        'subject41', 'subject42', 'subject43', 'subject44', 'subject45', 'subject46', 'subject47', 'subject48', 'subject49', 'subject50',
        'subject51', 'subject52', 'subject53', 'subject54', 'subject55', 'subject56', 'subject57', 'subject58', 'subject59', 'subject60',
        'subject61', 'subject62', 'subject63', 'subject64', 'subject65', 'subject66', 'subject67', 'subject68', 'subject69'
    ],
}
template_specifications = {
    'pulmonary artery': {'deformable_object_type': 'SurfaceMesh',
              'kernel_type': 'torch', 'kernel_width': 17.0, #Vary this one
              'noise_std': 2.0, #Vary this one
              'filename': os.path.join(data_base, 'Imbio58.vtk'),
              'attachment_type': 'Current',
              #'kernel_device' : 'cpu'
                }  
}

estimator_options={'optimization_method_type': 'GradientAscent', 
                   'initial_step_size': 0.01, #
                   'max_iterations': 500, #
                   'max_line_search_iterations': 10, 
                   'convergence_tolerance': 1e-4, #
                   'freeze_template': 'Off',
                   'number_of_processes': 4,
                   'callback': estimator_callback}

# deformation-parameters 
model_options={'deformation_kernel_type': 'torch', 
               'deformation_kernel_width': 17.0, #vary this one
               'dtype': 'float32'}


model = deformetrica.estimate_deterministic_atlas(template_specifications, dataset_specifications,
                                                estimator_options=estimator_options,
                                                model_options=model_options)
# Out:
# Logger has been set to: INFO
# >> No initial CP spacing given: using diffeo kernel width of 17.0
# OMP_NUM_THREADS was not found in environment variables. An automatic value will be set.
# OMP_NUM_THREADS will be set to 6
# >> No specified state-file. By default, Deformetrica state will by saved in file: ./clinicalPA_output/deformetrica-state.p.
# I detected 8 null area triangles, I am removing them
# I detected 4 null area triangles, I am removing them
# /opt/anaconda3/envs/deformetrica/lib/python3.8/site-packages/deformetrica/core/observations/deformable_objects/landmarks/surface_mesh.py:37: UserWarning: This overload of nonzero is deprecated:
# 	nonzero(Tensor input, *, Tensor out)
# Consider using one of the following signatures instead:
# 	nonzero(Tensor input, *, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   triangles_to_keep = torch.nonzero(torch.norm(normals, 2, 1) != 0)
# >> Set of 168 control points defined.
# >> Momenta initialized to zero, for 69 subjects.
# >> Started estimator: GradientAscent
# ------------------------------------- Iteration: 0 -------------------------------------
# >> Log-likelihood = -2.874E+08 	 [ attachment = -2.874E+08 ; regularity = 0.000E+00 ]
# >> Step size and gradient norm:
# 		4.075E-10   and   2.454E+07 	[ landmark_points ]
# 		1.275E-08   and   7.845E+05 	[ momenta ]
# ------------------------------------- Iteration: 1 -------------------------------------
# >> Log-likelihood = -2.874E+08 	 [ attachment = -2.874E+08 ; regularity = -2.648E-04 ]
# >> Step size and gradient norm:
# 		6.112E-10   and   2.454E+07 	[ landmark_points ]
# 		1.912E-08   and   7.844E+05 	[ momenta ]
# ------------------------------------- Iteration: 2 -------------------------------------
# >> Log-likelihood = -2.873E+08 	 [ attachment = -2.873E+08 ; regularity = -1.655E-03 ]
# >> Step size and gradient norm:
# 		9.169E-10   and   2.454E+07 	[ landmark_points ]
# 		2.868E-08   and   7.844E+05 	[ momenta ]
# ------------------------------------- Iteration: 3 -------------------------------------
# >> Log-likelihood = -2.873E+08 	 [ attachment = -2.873E+08 ; regularity = -5.974E-03 ]
# >> Step size and gradient norm:
# 		1.375E-09   and   2.454E+07 	[ landmark_points ]
# 		4.302E-08   and   7.844E+05 	[ momenta ]
# ------------------------------------- Iteration: 4 -------------------------------------
# >> Log-likelihood = -2.872E+08 	 [ attachment = -2.872E+08 ; regularity = -1.748E-02 ]
# >> Step size and gradient norm:
# 		2.063E-09   and   2.454E+07 	[ landmark_points ]
# 		6.454E-08   and   7.844E+05 	[ momenta ]
# ------------------------------------- Iteration: 5 -------------------------------------
# >> Log-likelihood = -2.872E+08 	 [ attachment = -2.872E+08 ; regularity = -4.604E-02 ]
# >> Step size and gradient norm:
# 		3.094E-09   and   2.453E+07 	[ landmark_points ]
# 		9.680E-08   and   7.843E+05 	[ momenta ]
# ------------------------------------- Iteration: 6 -------------------------------------
# >> Log-likelihood = -2.870E+08 	 [ attachment = -2.870E+08 ; regularity = -1.143E-01 ]
# >> Step size and gradient norm:
# 		4.642E-09   and   2.453E+07 	[ landmark_points ]
# 		1.452E-07   and   7.842E+05 	[ momenta ]
# ------------------------------------- Iteration: 7 -------------------------------------
# >> Log-likelihood = -2.868E+08 	 [ attachment = -2.868E+08 ; regularity = -2.740E-01 ]
# >> Step size and gradient norm:
# 		6.962E-09   and   2.453E+07 	[ landmark_points ]
# 		2.178E-07   and   7.841E+05 	[ momenta ]
# ------------------------------------- Iteration: 8 -------------------------------------
# >> Log-likelihood = -2.866E+08 	 [ attachment = -2.866E+08 ; regularity = -6.421E-01 ]
# >> Step size and gradient norm:
# 		1.044E-08   and   2.452E+07 	[ landmark_points ]
# 		3.267E-07   and   7.839E+05 	[ momenta ]
# ------------------------------------- Iteration: 9 -------------------------------------
# >> Log-likelihood = -2.862E+08 	 [ attachment = -2.862E+08 ; regularity = -1.484E+00 ]
# >> Step size and gradient norm:
# 		1.567E-08   and   2.451E+07 	[ landmark_points ]
# 		4.901E-07   and   7.836E+05 	[ momenta ]
# ------------------------------------- Iteration: 10 -------------------------------------
# >> Log-likelihood = -2.855E+08 	 [ attachment = -2.855E+08 ; regularity = -3.396E+00 ]
# >> Step size and gradient norm:
# 		2.350E-08   and   2.449E+07 	[ landmark_points ]
# 		7.351E-07   and   7.831E+05 	[ momenta ]
# ------------------------------------- Iteration: 11 -------------------------------------
# >> Log-likelihood = -2.846E+08 	 [ attachment = -2.846E+08 ; regularity = -7.726E+00 ]
# >> Step size and gradient norm:
# 		3.525E-08   and   2.446E+07 	[ landmark_points ]
# 		1.103E-06   and   7.824E+05 	[ momenta ]
# ------------------------------------- Iteration: 12 -------------------------------------
# >> Log-likelihood = -2.832E+08 	 [ attachment = -2.832E+08 ; regularity = -1.750E+01 ]
# >> Step size and gradient norm:
# 		5.287E-08   and   2.442E+07 	[ landmark_points ]
# 		1.654E-06   and   7.813E+05 	[ momenta ]
# ------------------------------------- Iteration: 13 -------------------------------------
# >> Log-likelihood = -2.812E+08 	 [ attachment = -2.812E+08 ; regularity = -3.951E+01 ]
# >> Step size and gradient norm:
# 		7.931E-08   and   2.436E+07 	[ landmark_points ]
# 		2.481E-06   and   7.796E+05 	[ momenta ]
# ------------------------------------- Iteration: 14 -------------------------------------
# >> Log-likelihood = -2.781E+08 	 [ attachment = -2.781E+08 ; regularity = -8.897E+01 ]
# >> Step size and gradient norm:
# 		1.190E-07   and   2.426E+07 	[ landmark_points ]
# 		3.721E-06   and   7.769E+05 	[ momenta ]
# ------------------------------------- Iteration: 15 -------------------------------------
# >> Log-likelihood = -2.735E+08 	 [ attachment = -2.735E+08 ; regularity = -1.998E+02 ]
# >> Step size and gradient norm:
# 		1.784E-07   and   2.410E+07 	[ landmark_points ]
# 		5.582E-06   and   7.725E+05 	[ momenta ]
# ------------------------------------- Iteration: 16 -------------------------------------
# >> Log-likelihood = -2.667E+08 	 [ attachment = -2.667E+08 ; regularity = -4.473E+02 ]
# >> Step size and gradient norm:
# 		2.677E-07   and   2.383E+07 	[ landmark_points ]
# 		8.373E-06   and   7.651E+05 	[ momenta ]
# ------------------------------------- Iteration: 17 -------------------------------------
# >> Log-likelihood = -2.567E+08 	 [ attachment = -2.567E+08 ; regularity = -9.963E+02 ]
# >> Step size and gradient norm:
# 		4.015E-07   and   2.335E+07 	[ landmark_points ]
# 		1.256E-05   and   7.522E+05 	[ momenta ]
# ------------------------------------- Iteration: 18 -------------------------------------
# >> Log-likelihood = -2.425E+08 	 [ attachment = -2.425E+08 ; regularity = -2.201E+03 ]
# >> Step size and gradient norm:
# 		6.022E-07   and   2.251E+07 	[ landmark_points ]
# 		1.884E-05   and   7.287E+05 	[ momenta ]
# ------------------------------------- Iteration: 19 -------------------------------------
# >> Log-likelihood = -2.228E+08 	 [ attachment = -2.228E+08 ; regularity = -4.791E+03 ]
# >> Step size and gradient norm:
# 		9.033E-07   and   2.095E+07 	[ landmark_points ]
# 		2.826E-05   and   6.843E+05 	[ momenta ]
# ------------------------------------- Iteration: 20 -------------------------------------
# >> Log-likelihood = -1.978E+08 	 [ attachment = -1.978E+08 ; regularity = -1.012E+04 ]
# >> Step size and gradient norm:
# 		1.355E-06   and   1.813E+07 	[ landmark_points ]
# 		4.239E-05   and   6.015E+05 	[ momenta ]
# ------------------------------------- Iteration: 21 -------------------------------------
# >> Log-likelihood = -1.707E+08 	 [ attachment = -1.707E+08 ; regularity = -2.014E+04 ]
# >> Step size and gradient norm:
# 		2.033E-06   and   1.371E+07 	[ landmark_points ]
# 		6.358E-05   and   4.652E+05 	[ momenta ]
# ------------------------------------- Iteration: 22 -------------------------------------
# >> Log-likelihood = -1.485E+08 	 [ attachment = -1.484E+08 ; regularity = -3.600E+04 ]
# >> Step size and gradient norm:
# 		3.049E-06   and   8.700E+06 	[ landmark_points ]
# 		9.538E-05   and   3.028E+05 	[ momenta ]
# ------------------------------------- Iteration: 23 -------------------------------------
# >> Log-likelihood = -1.351E+08 	 [ attachment = -1.351E+08 ; regularity = -5.584E+04 ]
# >> Step size and gradient norm:
# 		4.573E-06   and   4.975E+06 	[ landmark_points ]
# 		1.431E-04   and   1.768E+05 	[ momenta ]
# ------------------------------------- Iteration: 24 -------------------------------------
# >> Log-likelihood = -1.283E+08 	 [ attachment = -1.283E+08 ; regularity = -7.664E+04 ]
# >> Step size and gradient norm:
# 		6.860E-06   and   2.831E+06 	[ landmark_points ]
# 		2.146E-04   and   1.022E+05 	[ momenta ]
# ------------------------------------- Iteration: 25 -------------------------------------
# >> Log-likelihood = -1.249E+08 	 [ attachment = -1.248E+08 ; regularity = -9.718E+04 ]
# >> Step size and gradient norm:
# 		1.029E-05   and   1.655E+06 	[ landmark_points ]
# 		3.219E-04   and   6.075E+04 	[ momenta ]
# ------------------------------------- Iteration: 26 -------------------------------------
# >> Log-likelihood = -1.231E+08 	 [ attachment = -1.230E+08 ; regularity = -1.173E+05 ]
# >> Step size and gradient norm:
# 		1.543E-05   and   9.940E+05 	[ landmark_points ]
# 		4.828E-04   and   3.754E+04 	[ momenta ]
# ------------------------------------- Iteration: 27 -------------------------------------
# >> Log-likelihood = -1.221E+08 	 [ attachment = -1.219E+08 ; regularity = -1.372E+05 ]
# >> Step size and gradient norm:
# 		2.315E-05   and   6.101E+05 	[ landmark_points ]
# 		7.243E-04   and   2.451E+04 	[ momenta ]
# ------------------------------------- Iteration: 28 -------------------------------------
# >> Log-likelihood = -1.214E+08 	 [ attachment = -1.213E+08 ; regularity = -1.569E+05 ]
# >> Step size and gradient norm:
# 		3.473E-05   and   3.818E+05 	[ landmark_points ]
# 		1.086E-03   and   1.711E+04 	[ momenta ]
# ------------------------------------- Iteration: 29 -------------------------------------
# >> Log-likelihood = -1.210E+08 	 [ attachment = -1.208E+08 ; regularity = -1.769E+05 ]
# >> Step size and gradient norm:
# 		5.209E-05   and   2.512E+05 	[ landmark_points ]
# 		1.630E-03   and   1.575E+04 	[ momenta ]
# ------------------------------------- Iteration: 30 -------------------------------------
# >> Log-likelihood = -1.207E+08 	 [ attachment = -1.205E+08 ; regularity = -1.987E+05 ]
# >> Step size and gradient norm:
# 		7.814E-05   and   5.635E+05 	[ landmark_points ]
# 		2.444E-03   and   5.160E+04 	[ momenta ]
# >> Step size and gradient norm:
# 		3.907E-05   and   5.635E+05 	[ landmark_points ]
# 		1.222E-03   and   5.160E+04 	[ momenta ]
# >> Step size and gradient norm:
# 		1.953E-05   and   5.635E+05 	[ landmark_points ]
# 		6.111E-04   and   5.160E+04 	[ momenta ]
# >> Step size and gradient norm:
# 		9.767E-06   and   5.635E+05 	[ landmark_points ]
# 		3.055E-04   and   5.160E+04 	[ momenta ]
# ------------------------------------- Iteration: 31 -------------------------------------
# >> Log-likelihood = -1.206E+08 	 [ attachment = -1.204E+08 ; regularity = -2.000E+05 ]
# >> Step size and gradient norm:
# 		9.767E-06   and   4.977E+05 	[ landmark_points ]
# 		1.528E-04   and   3.854E+04 	[ momenta ]
# ------------------------------------- Iteration: 32 -------------------------------------
# >> Log-likelihood = -1.205E+08 	 [ attachment = -1.203E+08 ; regularity = -2.009E+05 ]
# >> Step size and gradient norm:
# 		1.465E-05   and   3.849E+05 	[ landmark_points ]
# 		2.292E-04   and   3.541E+04 	[ momenta ]
# ------------------------------------- Iteration: 33 -------------------------------------
# >> Log-likelihood = -1.205E+08 	 [ attachment = -1.203E+08 ; regularity = -2.019E+05 ]
# >> Step size and gradient norm:
# 		1.465E-05   and   3.197E+05 	[ landmark_points ]
# 		1.146E-04   and   2.166E+04 	[ momenta ]
# ------------------------------------- Iteration: 34 -------------------------------------
# >> Log-likelihood = -1.204E+08 	 [ attachment = -1.202E+08 ; regularity = -2.026E+05 ]
# >> Step size and gradient norm:
# 		2.198E-05   and   1.958E+05 	[ landmark_points ]
# 		1.719E-04   and   1.824E+04 	[ momenta ]
# ------------------------------------- Iteration: 35 -------------------------------------
# >> Log-likelihood = -1.204E+08 	 [ attachment = -1.202E+08 ; regularity = -2.039E+05 ]
# >> Step size and gradient norm:
# 		3.296E-05   and   3.457E+05 	[ landmark_points ]
# 		2.578E-04   and   2.395E+04 	[ momenta ]
# Tolerance threshold met. Stopping the optimization process.
# >> Estimation took: 05 minutes and 33 seconds

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# print available saved status keys
print(iteration_status_dictionaries[-1].keys())
# print(iteration_status_dictionaries[-1]['gradient'].keys())

y = [it_data['current_log_likelihood'] for it_data in iteration_status_dictionaries]
#print(len(y))
x = np.arange(1, estimator_options['max_iterations']+1)
x = np.arange(1, len(y)+1)

fig = plt.figure()

# plot log-likelihood
plt.plot(x, [it_data['current_log_likelihood'] for it_data in iteration_status_dictionaries], label='log_likelihood')
# plt.plot(x, [it_data['current_attachment'] for it_data in iteration_status_dictionaries], label='attachment')
# plt.plot(x, [it_data['current_regularity'] for it_data in iteration_status_dictionaries], label='regularity')

plt.xticks(x)

plt.style.use('default')
plt.legend()
plt.show()
# Out:
# dict_keys(['current_iteration', 'current_log_likelihood', 'current_attachment', 'current_regularity', 'gradient'])

# %%
####
#### LOAD RELEVANT INPUT DATA
####

import deformetrica as dfca

path_to_template_ini = template_specifications['pulmonary artery']['filename']
template_points__ini, dimension, template_connectivity__ini = dfca.io.DeformableObjectReader.read_file(path_to_template_ini, extract_connectivity=True)

####
#### LOAD RELEVANT OUTPUT DATA
####

fixed_effects = model.fixed_effects

template_points__est = fixed_effects['template_data']['landmark_points']
control_points__est = fixed_effects['control_points']
momenta__est = fixed_effects['momenta']

####
#### PLOT INITIAL AND ESTIMATED TEMPLATES
####

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib import cm
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

figsize = 5
f = plt.figure(figsize=(3*figsize, 1*figsize))
gs = gridspec.GridSpec(1, 3)

# Initial template
ax = plt.subplot(gs[0, 0])
p = template_points__ini
c = template_connectivity__ini
ax.plot([p[c[:,0]][:,0], p[c[:,1]][:,0]], 
        [p[c[:,0]][:,1], p[c[:,1]][:,1]], 'k', linewidth=4)
ax.set_title('Initial template')

# Estimated template
ax = plt.subplot(gs[0, 1])
p = template_points__est
ax.plot([p[c[:,0]][:,0], p[c[:,1]][:,0]], [p[c[:,0]][:,1], p[c[:,1]][:,1]], 'k', linewidth=4)
ax.set_title('Estimated template')

# Estimated template and momenta
ax = plt.subplot(gs[0, 2])
x = control_points__est
ax.plot([p[c[:,0]][:,0], p[c[:,1]][:,0]], [p[c[:,0]][:,1], p[c[:,1]][:,1]], 'k', linewidth=4)
cmap = cm.get_cmap('tab10')
for i, m in enumerate(momenta__est):
    color = cmap(i % 10)[:3]
    ax.quiver(x[:,0], x[:,1], m[:,0], m[:,1], color=color, width=0.01, scale=75)
ax.set_title('Estimated Template and Momenta')

####
#### PLOT RAW VERSUS RECONSTRUCTED DATA
####

import torch 

figsize = 3
f = plt.figure(figsize=(5*figsize, 1*figsize))
gs = gridspec.GridSpec(1, 5)

for i, momentum__est in enumerate(momenta__est): 
    ax = plt.subplot(gs[0, i])
    color = cmap(i % 10)[:3]
  
    # Load and plot raw target. 
    path_to_target__raw = dataset_specifications['dataset_filenames'][i][0]['pulmonary artery']
    target_id = dataset_specifications['subject_ids'][i]
    target_points__raw, _, target_connectivity__raw = dfca.io.DeformableObjectReader.read_file(path_to_target__raw, extract_connectivity=True)

    p = target_points__raw
    c = target_connectivity__raw
    ax.plot([p[c[:,0]][:,0], p[c[:,1]][:,0]], [p[c[:,0]][:,1], p[c[:,1]][:,1]], 'k', linewidth=2)
    ax.set_title(target_id)
  
    # Compute and plot the reconstruction of the target. 
    model.exponential.set_initial_momenta(torch.from_numpy(momentum__est).to(torch.float32))
    model.exponential.update()
    target_points__rec = model.exponential.get_template_points()['landmark_points'].detach().cpu().numpy()
  
    p = target_points__rec
    c = template_connectivity__ini
    ax.plot([p[c[:,0]][:,0], p[c[:,1]][:,0]], [p[c[:,0]][:,1], p[c[:,1]][:,1]], color=color, linewidth=2)

plt.style.use('default')
plt.show()
# Out:
# /tmp/ipykernel_621436/1102077210.py:52: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('tab10')
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 69
#      66 gs = gridspec.GridSpec(1, 5)
#      68 for i, momentum__est in enumerate(momenta__est):
# ---> 69     ax = plt.subplot(gs[0, i])
#      70     color = cmap(i % 10)[:3]
#      72     # Load and plot raw target.
#
# File /opt/anaconda3/envs/deformetrica/lib/python3.8/site-packages/matplotlib/gridspec.py:258, in GridSpecBase.__getitem__(self, key)
#     255     except ValueError as err:
#     256         raise ValueError("Unrecognized subplot spec") from err
#     257     num1, num2 = np.ravel_multi_index(
# --> 258         [_normalize(k1, nrows, 0), _normalize(k2, ncols, 1)],
#     259         (nrows, ncols))
#     260 else:  # Single key
#     261     num1, num2 = _normalize(key, nrows * ncols, None)
#
# File /opt/anaconda3/envs/deformetrica/lib/python3.8/site-packages/matplotlib/gridspec.py:246, in GridSpecBase.__getitem__.<locals>._normalize(key, size, axis)
#     244     return key, key
#     245 elif axis is not None:
# --> 246     raise IndexError(f"index {orig_key} is out of bounds for "
#     247                      f"axis {axis} with size {size}")
#     248 else:  # flat index
#     249     raise IndexError(f"index {orig_key} is out of bounds for "
#     250                      f"GridSpec with size {size}")
#
# IndexError: index 5 is out of bounds for axis 1 with size 5

# %%
### CHOOSE WHICH ORGAN TO PLOT
organ = 'hippo'
organ = 'amygdala'

path_to_template__ini = template_specifications[organ]['filename']
template_points__ini, dimension, template_connectivity__ini = dfca.io.DeformableObjectReader.read_file(path_to_template__ini, extract_connectivity=True)

####
#### LOAD RELEVANT OUTPUT DATA
####

fixed_effects = model.fixed_effects

template_points__est = fixed_effects['template_data']['landmark_points']
control_points__est = fixed_effects['control_points']
momenta__est = fixed_effects['momenta']

####
#### PLOT INITIAL AND ESTIMATED TEMPLATES
####

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib import cm
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

figsize = 5
f = plt.figure(figsize=(3*figsize, 1*figsize))
gs = gridspec.GridSpec(1, 3)

# Initial template
ax = plt.subplot(gs[0, 0], projection='3d')
p = template_points__ini
c = template_connectivity__ini
for i in range(0, len(p[c[:,0]][:,0])):
    ax.plot3D(
        [p[c[:,0]][:,0][i], p[c[:,1]][:,0][i]],
        [p[c[:,0]][:,1][i], p[c[:,1]][:,1][i]],
        [p[c[:,0]][:,2][i], p[c[:,1]][:,2][i]],
        color='k', linewidth=1)
ax.set_title('Initial template')
ax.view_init(120, -90)

# Estimated template
ax = plt.subplot(gs[0, 1], projection='3d')
p = template_points__est
for i in range(0, len(p[c[:,0]][:,0])):
    ax.plot3D(
        [p[c[:,0]][:,0][i], p[c[:,1]][:,0][i]],
        [p[c[:,0]][:,1][i], p[c[:,1]][:,1][i]],
        [p[c[:,0]][:,2][i], p[c[:,1]][:,2][i]],
        color='k', linewidth=1)
ax.set_title('Estimated template')
ax.view_init(120, -90)

# Estimated template and momenta
ax = plt.subplot(gs[0, 2], projection='3d')
x = control_points__est
for i in range(0, len(p[c[:,0]][:,0])):
    ax.plot3D(
        [p[c[:,0]][:,0][i], p[c[:,1]][:,0][i]],
        [p[c[:,0]][:,1][i], p[c[:,1]][:,1][i]],
        [p[c[:,0]][:,2][i], p[c[:,1]][:,2][i]],
        color='k', linewidth=1) 
    
cmap = cm.get_cmap('tab10')
for i, m in enumerate(momenta__est):
    color = cmap(i % 10)[:3]
    ax.quiver3D(x[:,0], x[:,1], x[:,2], 
                m[:,0], m[:,1], m[:,2], 
                #m[0], m[1], m[2], 
                color=color, 
                length=20,
#                 width=0.01, 
#                 scale=75
               )
ax.set_title('Estimated template and momenta')
ax.view_init(120, -90)

plt.style.use('default')
plt.show()

####
#### PLOT RAW VERSUS RECONSTRUCTED DATA
####

import torch 

figsize = 3
f = plt.figure(figsize=(5*figsize, 1*figsize))
gs = gridspec.GridSpec(1, 5)

for i, momentum__est in enumerate(momenta__est): 
    ax = plt.subplot(gs[0, i], projection='3d')
    color = cmap(i % 10)[:3]
  
    # Load and plot raw target. 
    path_to_target__raw = dataset_specifications['dataset_filenames'][i][0][organ]
    print(path_to_target__raw)
    target_id = dataset_specifications['subject_ids'][i]
    target_points__raw, _, target_connectivity__raw = dfca.io.DeformableObjectReader.read_file(path_to_target__raw, extract_connectivity=True)

    p = target_points__raw
    c = target_connectivity__raw
    for i in range(0, len(p[c[:,0]][:,0])):
        ax.plot3D(
            [p[c[:,0]][:,0][i], p[c[:,1]][:,0][i]],
            [p[c[:,0]][:,1][i], p[c[:,1]][:,1][i]],
            [p[c[:,0]][:,2][i], p[c[:,1]][:,2][i]],
            color='k', linewidth=1)
    #ax.plot([p[c[:,0]][:,0], p[c[:,1]][:,0]], [p[c[:,0]][:,1], p[c[:,1]][:,1]], 'k', linewidth=2)
    ax.set_title(target_id)
  
    # Compute and plot the reconstruction of the target. 
    model.exponential.set_initial_momenta(torch.from_numpy(momentum__est).to(torch.float32))
    model.exponential.update()
    target_points__rec = model.exponential.get_template_points()['landmark_points'].detach().cpu().numpy()
  
    p = target_points__rec
    c = template_connectivity__ini
    #ax.plot([p[c[:,0]][:,0], p[c[:,1]][:,0]], [p[c[:,0]][:,1], p[c[:,1]][:,1]], color=color, linewidth=2)
    for i in range(0, len(p[c[:,0]][:,0])):
        ax.plot3D(
            [p[c[:,0]][:,0][i], p[c[:,1]][:,0][i]],
            [p[c[:,0]][:,1][i], p[c[:,1]][:,1][i]],
            [p[c[:,0]][:,2][i], p[c[:,1]][:,2][i]],
            color=color, linewidth=1)

plt.style.use('default')
plt.show()

# %%
import os
import deformetrica as dfca

#organ = 'hippo'
organ = 'amygdala'

### EDIT THESE PATHS #####################
data_path = '/u/i/sm2894/Documents/FYP/'
data_base = os.path.join(data_path, 'Data/clinical sm/')

output_directory = './brain_' + organ + '_output/' #directory where the outputs will be saved
########################################

iteration_status_dictionaries = []

def estimator_callback(status_dict):
    iteration_status_dictionaries.append(status_dict)
    return True

# instantiate a Deformetrica object
deformetrica = dfca.Deformetrica(output_dir=output_directory, verbosity='INFO')

dataset_specifications = {
    'dataset_filenames': [
        [{organ: os.path.join(data_base, organ + '1.vtk')}],
        [{organ: os.path.join(data_base, organ + '2.vtk')}],
        [{organ: os.path.join(data_base, organ + '3.vtk')}],
        [{organ: os.path.join(data_base, organ + '4.vtk')}]
    ],
    'subject_ids': ['subject1', 'subject2', 'subject3', 'subject4'],
}
if organ == "hippo":
    template_name = 'hippo_prototype.vtk'
elif organ == "amygdala":
    template_name = 'amyg_prototype.vtk'
    
template_specifications = {
    organ: {'deformable_object_type': 'SurfaceMesh',
              'kernel_type': 'torch', 'kernel_width': 25.0, #Vary this
              'noise_std': 10.0, #Vary this
              'filename': os.path.join(data_base, template_name),
              'attachment_type': 'Current',
              #'kernel_device' : 'cpu'
                },   
}

#estimator_options={'optimization_method_type': 'GradientAscent', 'initial_step_size': 1.,
#                   'max_iterations': 100, 'max_line_search_iterations': 20, 'callback': estimator_callback}

estimator_options={'optimization_method_type': 'GradientAscent', 
                   'initial_step_size': 0.01, #
                   'max_iterations': 500, #
                   'max_line_search_iterations': 10, 
                   'convergence_tolerance': 1e-4, #
                   'freeze_template': 'Off',
                   'number_of_processes': 4,
                   'callback': estimator_callback}

# deformation-parameters 
model_options={'deformation_kernel_type': 'torch', 
               'deformation_kernel_width': 25.0, #Vary this
               'dtype': 'float32'}


model = deformetrica.estimate_deterministic_atlas(template_specifications, dataset_specifications,
                                                estimator_options=estimator_options,
                                                model_options=model_options)

# %%
### CHOOSE WHICH ORGAN TO PLOT


path_to_template__ini = template_specifications[organ]['filename']
template_points__ini, dimension, template_connectivity__ini = dfca.io.DeformableObjectReader.read_file(path_to_template__ini, extract_connectivity=True)

####
#### LOAD RELEVANT OUTPUT DATA
####

fixed_effects = model.fixed_effects

template_points__est = fixed_effects['template_data']['landmark_points']
control_points__est = fixed_effects['control_points']
momenta__est = fixed_effects['momenta']

####
#### PLOT INITIAL AND ESTIMATED TEMPLATES
####

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib import cm
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

figsize = 5
f = plt.figure(figsize=(3*figsize, 1*figsize))
gs = gridspec.GridSpec(1, 3)

# Initial template
ax = plt.subplot(gs[0, 0], projection='3d')
p = template_points__ini
c = template_connectivity__ini
for i in range(0, len(p[c[:,0]][:,0])):
    ax.plot3D(
        [p[c[:,0]][:,0][i], p[c[:,1]][:,0][i]],
        [p[c[:,0]][:,1][i], p[c[:,1]][:,1][i]],
        [p[c[:,0]][:,2][i], p[c[:,1]][:,2][i]],
        color='k', linewidth=1)
ax.set_title('Initial template')
ax.view_init(120, -90)

# Estimated template
ax = plt.subplot(gs[0, 1], projection='3d')
p = template_points__est
for i in range(0, len(p[c[:,0]][:,0])):
    ax.plot3D(
        [p[c[:,0]][:,0][i], p[c[:,1]][:,0][i]],
        [p[c[:,0]][:,1][i], p[c[:,1]][:,1][i]],
        [p[c[:,0]][:,2][i], p[c[:,1]][:,2][i]],
        color='k', linewidth=1)
ax.set_title('Estimated template')
ax.view_init(120, -90)

# Estimated template and momenta
ax = plt.subplot(gs[0, 2], projection='3d')
x = control_points__est
for i in range(0, len(p[c[:,0]][:,0])):
    ax.plot3D(
        [p[c[:,0]][:,0][i], p[c[:,1]][:,0][i]],
        [p[c[:,0]][:,1][i], p[c[:,1]][:,1][i]],
        [p[c[:,0]][:,2][i], p[c[:,1]][:,2][i]],
        color='k', linewidth=1) 
    
cmap = cm.get_cmap('tab10')
for i, m in enumerate(momenta__est):
    color = cmap(i % 10)[:3]
    ax.quiver3D(x[:,0], x[:,1], x[:,2], 
                m[:,0], m[:,1], m[:,2], 
                #m[0], m[1], m[2], 
                color=color, 
                length=20,
#                 width=0.01, 
#                 scale=75
               )
ax.set_title('Estimated template and momenta')
ax.view_init(120, -90)

plt.style.use('default')
plt.show()

####
#### PLOT RAW VERSUS RECONSTRUCTED DATA
####

import torch 

figsize = 3
f = plt.figure(figsize=(5*figsize, 1*figsize))
gs = gridspec.GridSpec(1, 5)

for i, momentum__est in enumerate(momenta__est): 
    ax = plt.subplot(gs[0, i], projection='3d')
    color = cmap(i % 10)[:3]
  
    # Load and plot raw target. 
    path_to_target__raw = dataset_specifications['dataset_filenames'][i][0][organ]
    print(path_to_target__raw)
    target_id = dataset_specifications['subject_ids'][i]
    target_points__raw, _, target_connectivity__raw = dfca.io.DeformableObjectReader.read_file(path_to_target__raw, extract_connectivity=True)

    p = target_points__raw
    c = target_connectivity__raw
    for i in range(0, len(p[c[:,0]][:,0])):
        ax.plot3D(
            [p[c[:,0]][:,0][i], p[c[:,1]][:,0][i]],
            [p[c[:,0]][:,1][i], p[c[:,1]][:,1][i]],
            [p[c[:,0]][:,2][i], p[c[:,1]][:,2][i]],
            color='k', linewidth=1)
    #ax.plot([p[c[:,0]][:,0], p[c[:,1]][:,0]], [p[c[:,0]][:,1], p[c[:,1]][:,1]], 'k', linewidth=2)
    ax.set_title(target_id)
  
    # Compute and plot the reconstruction of the target. 
    model.exponential.set_initial_momenta(torch.from_numpy(momentum__est).to(torch.float32))
    model.exponential.update()
    target_points__rec = model.exponential.get_template_points()['landmark_points'].detach().cpu().numpy()
  
    p = target_points__rec
    c = template_connectivity__ini
    #ax.plot([p[c[:,0]][:,0], p[c[:,1]][:,0]], [p[c[:,0]][:,1], p[c[:,1]][:,1]], color=color, linewidth=2)
    for i in range(0, len(p[c[:,0]][:,0])):
        ax.plot3D(
            [p[c[:,0]][:,0][i], p[c[:,1]][:,0][i]],
            [p[c[:,0]][:,1][i], p[c[:,1]][:,1][i]],
            [p[c[:,0]][:,2][i], p[c[:,1]][:,2][i]],
            color=color, linewidth=1)

plt.style.use('default')
plt.show()
