# %%
import os
import glob
import re
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import deformetrica as dfca

# %%
#Visualise the data:
data_path = '/u/i/sm2894/Documents/FYP/Data/'
data_base = os.path.join(data_path, 'primed/DataAO/')

vtk_files = glob.glob(data_base + "*.vtk")

vtk_file =vtk_files[0]
print(vtk_file)
target_points__raw, _, target_connectivity__raw = dfca.io.DeformableObjectReader.read_file(vtk_file, extract_connectivity=True)
print(target_points__raw.shape)
print(target_connectivity__raw.shape)

figsize = 5
f = plt.figure(figsize=(5 * figsize, 1 * figsize))
gs = gridspec.GridSpec(1, len(vtk_files))

for i, vtk_file in enumerate(vtk_files):
    ax = plt.subplot(gs[0, i])
    # color = cmap(i % 10)[:3]

    m = re.findall(r".*\/(.*)\..*", vtk_file)
    target_id = m[0]
    target_points__raw, _, target_connectivity__raw = dfca.io.DeformableObjectReader.read_file(vtk_file, extract_connectivity=True)

    p = target_points__raw
    c = target_connectivity__raw
    ax.plot([p[c[:, 0]][:, 0], p[c[:, 1]][:, 0]],
            [p[c[:, 0]][:, 1], p[c[:, 1]][:, 1]],
            'k', linewidth=2)
    ax.set_title(target_id)

plt.style.use('default')
plt.show()

# %%
import os
import deformetrica as dfca

### EDIT THESE PATHS #####################
data_path = '/u/i/sm2894/Documents/FYP/Data/'
data_base = os.path.join(data_path, 'primed/DataAO/')

output_directory = './clinicalAO_output/' #directory where the outputs will be saved
########################################

iteration_status_dictionaries = []

def estimator_callback(status_dict):
    iteration_status_dictionaries.append(status_dict)
    return True

# instantiate a Deformetrica object
deformetrica = dfca.Deformetrica(output_dir=output_directory, verbosity='INFO')

dataset_specifications = {
    'dataset_filenames': [
        [{'aorta': os.path.join(data_base, 'Imbio01.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio02.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio03.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio05.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio06.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio07.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio08.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio09.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio10.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio11.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio12.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio15.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio16.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio17.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio18.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio19.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio20.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio21.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio22.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio23.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio24.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio25.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio26.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio29.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio30.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio31.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio32.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio33.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio34.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio36.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio37.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio38.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio39.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio40.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio41.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio43.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio44.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio45.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio46.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio47.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio48.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio49.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio50.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio51.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio52.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio53.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio54.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio55.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio56.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio57.vtk')}],
        [{'aorta': os.path.join(data_base, 'Imbio59.vtk')}],
        [{'aorta': os.path.join(data_base, 'S01.vtk')}],
        [{'aorta': os.path.join(data_base, 'S02.vtk')}],
        [{'aorta': os.path.join(data_base, 'S03.vtk')}],
        [{'aorta': os.path.join(data_base, 'S04.vtk')}],
        [{'aorta': os.path.join(data_base, 'S05.vtk')}],
        [{'aorta': os.path.join(data_base, 'S08.vtk')}],
        [{'aorta': os.path.join(data_base, 'S09.vtk')}],
        [{'aorta': os.path.join(data_base, 'S10.vtk')}],
        [{'aorta': os.path.join(data_base, 'S11.vtk')}],
        [{'aorta': os.path.join(data_base, 'S12.vtk')}],
        [{'aorta': os.path.join(data_base, 'S13.vtk')}],
        [{'aorta': os.path.join(data_base, 'S14.vtk')}],
        [{'aorta': os.path.join(data_base, 'S15.vtk')}],
        [{'aorta': os.path.join(data_base, 'S16.vtk')}],
        [{'aorta': os.path.join(data_base, 'S17.vtk')}],
        [{'aorta': os.path.join(data_base, 'S18.vtk')}],
        [{'aorta': os.path.join(data_base, 'S19.vtk')}],
        [{'aorta': os.path.join(data_base, 'S20.vtk')}]
    ],
    'subject_ids': [
        'subject1', 'subject2', 'subject3', 'subject4', 'subject5', 'subject6', 'subject7', 'subject8', 'subject9', 'subject10',
        'subject11', 'subject12', 'subject13', 'subject14', 'subject15', 'subject16', 'subject17', 'subject18', 'subject19', 'subject20',
        'subject21', 'subject22', 'subject23', 'subject24', 'subject25', 'subject26', 'subject27', 'subject28', 'subject29', 'subject30',
        'subject31', 'subject32', 'subject33', 'subject34', 'subject35', 'subject36', 'subject37', 'subject38', 'subject39', 'subject40',
        'subject41', 'subject42', 'subject43', 'subject44', 'subject45', 'subject46', 'subject47', 'subject48', 'subject49', 'subject50',
        'subject51', 'subject52', 'subject53', 'subject54', 'subject55', 'subject56', 'subject57', 'subject58', 'subject59', 'subject60',
        'subject61', 'subject62', 'subject63', 'subject64', 'subject65', 'subject66', 'subject67', 'subject68', 'subject69'
    ],
}
template_specifications = {
    'aorta': {'deformable_object_type': 'SurfaceMesh',
              'kernel_type': 'torch', 'kernel_width': 18.0, #Vary this one
              'noise_std': 2.0, #Vary this one
              'filename': os.path.join(data_base, 'Imbio58.vtk'),
              'attachment_type': 'Current',
              #'kernel_device' : 'cpu'
                }  
}

estimator_options={'optimization_method_type': 'GradientAscent', 
                   'initial_step_size': 0.01, #
                   'max_iterations': 500, #
                   'max_line_search_iterations': 10, 
                   'convergence_tolerance': 1e-4, #
                   'freeze_template': 'Off',
                   'number_of_processes': 4,
                   'callback': estimator_callback}

# deformation-parameters 
model_options={'deformation_kernel_type': 'torch', 
               'deformation_kernel_width': 18.0, #vary this one
               'dtype': 'float32'}


model = deformetrica.estimate_deterministic_atlas(template_specifications, dataset_specifications,
                                                estimator_options=estimator_options,
                                                model_options=model_options)
# Out:
# Logger has been set to: INFO
# >> No initial CP spacing given: using diffeo kernel width of 18.0
# OMP_NUM_THREADS was not found in environment variables. An automatic value will be set.
# OMP_NUM_THREADS will be set to 6
# >> No specified state-file. By default, Deformetrica state will by saved in file: ./clinicalAO_output/deformetrica-state.p.
# I detected 15 null area triangles, I am removing them
# /opt/anaconda3/envs/deformetrica/lib/python3.8/site-packages/deformetrica/core/observations/deformable_objects/landmarks/surface_mesh.py:37: UserWarning: This overload of nonzero is deprecated:
# 	nonzero(Tensor input, *, Tensor out)
# Consider using one of the following signatures instead:
# 	nonzero(Tensor input, *, bool as_tuple) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:766.)
#   triangles_to_keep = torch.nonzero(torch.norm(normals, 2, 1) != 0)
# >> Set of 280 control points defined.
# >> Momenta initialized to zero, for 69 subjects.
# >> Started estimator: GradientAscent
# ------------------------------------- Iteration: 0 -------------------------------------
# >> Log-likelihood = -5.930E+08 	 [ attachment = -5.930E+08 ; regularity = 0.000E+00 ]
# >> Step size and gradient norm:
# 		2.389E-10   and   4.186E+07 	[ landmark_points ]
# 		8.362E-09   and   1.196E+06 	[ momenta ]
# ------------------------------------- Iteration: 1 -------------------------------------
# >> Log-likelihood = -5.930E+08 	 [ attachment = -5.930E+08 ; regularity = -2.864E-04 ]
# >> Step size and gradient norm:
# 		3.583E-10   and   4.186E+07 	[ landmark_points ]
# 		1.254E-08   and   1.196E+06 	[ momenta ]
# ------------------------------------- Iteration: 2 -------------------------------------
# >> Log-likelihood = -5.929E+08 	 [ attachment = -5.929E+08 ; regularity = -1.790E-03 ]
# >> Step size and gradient norm:
# 		5.375E-10   and   4.186E+07 	[ landmark_points ]
# 		1.881E-08   and   1.196E+06 	[ momenta ]
# ------------------------------------- Iteration: 3 -------------------------------------
# >> Log-likelihood = -5.929E+08 	 [ attachment = -5.929E+08 ; regularity = -6.462E-03 ]
# >> Step size and gradient norm:
# 		8.063E-10   and   4.186E+07 	[ landmark_points ]
# 		2.822E-08   and   1.196E+06 	[ momenta ]
# ------------------------------------- Iteration: 4 -------------------------------------
# >> Log-likelihood = -5.928E+08 	 [ attachment = -5.928E+08 ; regularity = -1.891E-02 ]
# >> Step size and gradient norm:
# 		1.209E-09   and   4.186E+07 	[ landmark_points ]
# 		4.233E-08   and   1.196E+06 	[ momenta ]
# ------------------------------------- Iteration: 5 -------------------------------------
# >> Log-likelihood = -5.927E+08 	 [ attachment = -5.927E+08 ; regularity = -4.981E-02 ]
# >> Step size and gradient norm:
# 		1.814E-09   and   4.186E+07 	[ landmark_points ]
# 		6.350E-08   and   1.196E+06 	[ momenta ]
# ------------------------------------- Iteration: 6 -------------------------------------
# >> Log-likelihood = -5.925E+08 	 [ attachment = -5.925E+08 ; regularity = -1.237E-01 ]
# >> Step size and gradient norm:
# 		2.721E-09   and   4.186E+07 	[ landmark_points ]
# 		9.524E-08   and   1.196E+06 	[ momenta ]
# ------------------------------------- Iteration: 7 -------------------------------------
# >> Log-likelihood = -5.923E+08 	 [ attachment = -5.923E+08 ; regularity = -2.965E-01 ]
# >> Step size and gradient norm:
# 		4.082E-09   and   4.187E+07 	[ landmark_points ]
# 		1.429E-07   and   1.196E+06 	[ momenta ]
# ------------------------------------- Iteration: 8 -------------------------------------
# >> Log-likelihood = -5.919E+08 	 [ attachment = -5.919E+08 ; regularity = -6.950E-01 ]
# >> Step size and gradient norm:
# 		6.123E-09   and   4.187E+07 	[ landmark_points ]
# 		2.143E-07   and   1.196E+06 	[ momenta ]
# ------------------------------------- Iteration: 9 -------------------------------------
# >> Log-likelihood = -5.914E+08 	 [ attachment = -5.914E+08 ; regularity = -1.606E+00 ]
# >> Step size and gradient norm:
# 		9.184E-09   and   4.188E+07 	[ landmark_points ]
# 		3.214E-07   and   1.196E+06 	[ momenta ]
# ------------------------------------- Iteration: 10 -------------------------------------
# >> Log-likelihood = -5.905E+08 	 [ attachment = -5.905E+08 ; regularity = -3.680E+00 ]
# >> Step size and gradient norm:
# 		1.378E-08   and   4.188E+07 	[ landmark_points ]
# 		4.822E-07   and   1.197E+06 	[ momenta ]
# ------------------------------------- Iteration: 11 -------------------------------------
# >> Log-likelihood = -5.893E+08 	 [ attachment = -5.893E+08 ; regularity = -8.378E+00 ]
# >> Step size and gradient norm:
# 		2.066E-08   and   4.190E+07 	[ landmark_points ]
# 		7.232E-07   and   1.197E+06 	[ momenta ]
# ------------------------------------- Iteration: 12 -------------------------------------
# >> Log-likelihood = -5.874E+08 	 [ attachment = -5.874E+08 ; regularity = -1.900E+01 ]
# >> Step size and gradient norm:
# 		3.100E-08   and   4.191E+07 	[ landmark_points ]
# 		1.085E-06   and   1.197E+06 	[ momenta ]
# ------------------------------------- Iteration: 13 -------------------------------------
# >> Log-likelihood = -5.846E+08 	 [ attachment = -5.846E+08 ; regularity = -4.299E+01 ]
# >> Step size and gradient norm:
# 		4.649E-08   and   4.194E+07 	[ landmark_points ]
# 		1.627E-06   and   1.198E+06 	[ momenta ]
# ------------------------------------- Iteration: 14 -------------------------------------
# >> Log-likelihood = -5.804E+08 	 [ attachment = -5.804E+08 ; regularity = -9.711E+01 ]
# >> Step size and gradient norm:
# 		6.974E-08   and   4.198E+07 	[ landmark_points ]
# 		2.441E-06   and   1.199E+06 	[ momenta ]
# ------------------------------------- Iteration: 15 -------------------------------------
# >> Log-likelihood = -5.741E+08 	 [ attachment = -5.741E+08 ; regularity = -2.192E+02 ]
# >> Step size and gradient norm:
# 		1.046E-07   and   4.202E+07 	[ landmark_points ]
# 		3.661E-06   and   1.200E+06 	[ momenta ]
# ------------------------------------- Iteration: 16 -------------------------------------
# >> Log-likelihood = -5.646E+08 	 [ attachment = -5.646E+08 ; regularity = -4.943E+02 ]
# >> Step size and gradient norm:
# 		1.569E-07   and   4.208E+07 	[ landmark_points ]
# 		5.492E-06   and   1.202E+06 	[ momenta ]
# ------------------------------------- Iteration: 17 -------------------------------------
# >> Log-likelihood = -5.504E+08 	 [ attachment = -5.503E+08 ; regularity = -1.115E+03 ]
# >> Step size and gradient norm:
# 		2.354E-07   and   4.213E+07 	[ landmark_points ]
# 		8.238E-06   and   1.204E+06 	[ momenta ]
# ------------------------------------- Iteration: 18 -------------------------------------
# >> Log-likelihood = -5.289E+08 	 [ attachment = -5.289E+08 ; regularity = -2.513E+03 ]
# >> Step size and gradient norm:
# 		3.531E-07   and   4.212E+07 	[ landmark_points ]
# 		1.236E-05   and   1.205E+06 	[ momenta ]
# ------------------------------------- Iteration: 19 -------------------------------------
# >> Log-likelihood = -4.969E+08 	 [ attachment = -4.969E+08 ; regularity = -5.661E+03 ]
# >> Step size and gradient norm:
# 		5.296E-07   and   4.185E+07 	[ landmark_points ]
# 		1.854E-05   and   1.201E+06 	[ momenta ]
# ------------------------------------- Iteration: 20 -------------------------------------
# >> Log-likelihood = -4.498E+08 	 [ attachment = -4.498E+08 ; regularity = -1.270E+04 ]
# >> Step size and gradient norm:
# 		7.944E-07   and   4.080E+07 	[ landmark_points ]
# 		2.780E-05   and   1.177E+06 	[ momenta ]
# ------------------------------------- Iteration: 21 -------------------------------------
# >> Log-likelihood = -3.840E+08 	 [ attachment = -3.839E+08 ; regularity = -2.812E+04 ]
# >> Step size and gradient norm:
# 		1.192E-06   and   3.749E+07 	[ landmark_points ]
# 		4.171E-05   and   1.095E+06 	[ momenta ]
# ------------------------------------- Iteration: 22 -------------------------------------
# >> Log-likelihood = -3.051E+08 	 [ attachment = -3.050E+08 ; regularity = -5.965E+04 ]
# >> Step size and gradient norm:
# 		1.787E-06   and   2.942E+07 	[ landmark_points ]
# 		6.256E-05   and   8.770E+05 	[ momenta ]
# ------------------------------------- Iteration: 23 -------------------------------------
# >> Log-likelihood = -2.393E+08 	 [ attachment = -2.392E+08 ; regularity = -1.129E+05 ]
# >> Step size and gradient norm:
# 		2.681E-06   and   1.740E+07 	[ landmark_points ]
# 		9.384E-05   and   5.309E+05 	[ momenta ]
# ------------------------------------- Iteration: 24 -------------------------------------
# >> Log-likelihood = -2.067E+08 	 [ attachment = -2.065E+08 ; regularity = -1.760E+05 ]
# >> Step size and gradient norm:
# 		4.022E-06   and   8.656E+06 	[ landmark_points ]
# 		1.408E-04   and   2.694E+05 	[ momenta ]
# ------------------------------------- Iteration: 25 -------------------------------------
# >> Log-likelihood = -1.941E+08 	 [ attachment = -1.939E+08 ; regularity = -2.331E+05 ]
# >> Step size and gradient norm:
# 		6.032E-06   and   4.514E+06 	[ landmark_points ]
# 		2.111E-04   and   1.444E+05 	[ momenta ]
# ------------------------------------- Iteration: 26 -------------------------------------
# >> Log-likelihood = -1.886E+08 	 [ attachment = -1.883E+08 ; regularity = -2.837E+05 ]
# >> Step size and gradient norm:
# 		9.048E-06   and   2.529E+06 	[ landmark_points ]
# 		3.167E-04   and   8.650E+04 	[ momenta ]
# ------------------------------------- Iteration: 27 -------------------------------------
# >> Log-likelihood = -1.857E+08 	 [ attachment = -1.853E+08 ; regularity = -3.312E+05 ]
# >> Step size and gradient norm:
# 		1.357E-05   and   1.493E+06 	[ landmark_points ]
# 		4.751E-04   and   5.784E+04 	[ momenta ]
# ------------------------------------- Iteration: 28 -------------------------------------
# >> Log-likelihood = -1.838E+08 	 [ attachment = -1.834E+08 ; regularity = -3.779E+05 ]
# >> Step size and gradient norm:
# 		2.036E-05   and   9.199E+05 	[ landmark_points ]
# 		7.126E-04   and   4.746E+04 	[ momenta ]
# ------------------------------------- Iteration: 29 -------------------------------------
# >> Log-likelihood = -1.825E+08 	 [ attachment = -1.821E+08 ; regularity = -4.244E+05 ]
# >> Step size and gradient norm:
# 		3.054E-05   and   1.066E+06 	[ landmark_points ]
# 		1.069E-03   and   9.557E+04 	[ momenta ]
# >> Step size and gradient norm:
# 		1.527E-05   and   1.066E+06 	[ landmark_points ]
# 		5.344E-04   and   9.557E+04 	[ momenta ]
# >> Step size and gradient norm:
# 		7.635E-06   and   1.066E+06 	[ landmark_points ]
# 		2.672E-04   and   9.557E+04 	[ momenta ]
# ------------------------------------- Iteration: 30 -------------------------------------
# >> Log-likelihood = -1.821E+08 	 [ attachment = -1.816E+08 ; regularity = -4.324E+05 ]
# >> Step size and gradient norm:
# 		7.635E-06   and   9.315E+05 	[ landmark_points ]
# 		1.336E-04   and   7.900E+04 	[ momenta ]
# ------------------------------------- Iteration: 31 -------------------------------------
# >> Log-likelihood = -1.818E+08 	 [ attachment = -1.813E+08 ; regularity = -4.365E+05 ]
# >> Step size and gradient norm:
# 		1.145E-05   and   8.212E+05 	[ landmark_points ]
# 		2.004E-04   and   7.401E+04 	[ momenta ]
# ------------------------------------- Iteration: 32 -------------------------------------
# >> Log-likelihood = -1.815E+08 	 [ attachment = -1.810E+08 ; regularity = -4.416E+05 ]
# >> Step size and gradient norm:
# 		1.145E-05   and   6.450E+05 	[ landmark_points ]
# 		1.002E-04   and   5.299E+04 	[ momenta ]
# ------------------------------------- Iteration: 33 -------------------------------------
# >> Log-likelihood = -1.813E+08 	 [ attachment = -1.808E+08 ; regularity = -4.448E+05 ]
# >> Step size and gradient norm:
# 		1.718E-05   and   4.950E+05 	[ landmark_points ]
# 		1.503E-04   and   4.347E+04 	[ momenta ]
# ------------------------------------- Iteration: 34 -------------------------------------
# >> Log-likelihood = -1.811E+08 	 [ attachment = -1.806E+08 ; regularity = -4.509E+05 ]
# >> Step size and gradient norm:
# 		2.577E-05   and   6.850E+05 	[ landmark_points ]
# 		2.255E-04   and   5.385E+04 	[ momenta ]
# ------------------------------------- Iteration: 35 -------------------------------------
# >> Log-likelihood = -1.810E+08 	 [ attachment = -1.805E+08 ; regularity = -4.536E+05 ]
# >> Step size and gradient norm:
# 		2.577E-05   and   8.600E+05 	[ landmark_points ]
# 		1.127E-04   and   6.934E+04 	[ momenta ]
# ------------------------------------- Iteration: 36 -------------------------------------
# >> Log-likelihood = -1.808E+08 	 [ attachment = -1.803E+08 ; regularity = -4.558E+05 ]
# >> Step size and gradient norm:
# 		2.577E-05   and   6.372E+05 	[ landmark_points ]
# 		5.637E-05   and   4.470E+04 	[ momenta ]
# ------------------------------------- Iteration: 37 -------------------------------------
# >> Log-likelihood = -1.807E+08 	 [ attachment = -1.802E+08 ; regularity = -4.570E+05 ]
# >> Step size and gradient norm:
# 		3.865E-05   and   4.214E+05 	[ landmark_points ]
# 		8.455E-05   and   3.848E+04 	[ momenta ]
# ------------------------------------- Iteration: 38 -------------------------------------
# >> Log-likelihood = -1.806E+08 	 [ attachment = -1.801E+08 ; regularity = -4.595E+05 ]
# >> Step size and gradient norm:
# 		5.798E-05   and   6.646E+05 	[ landmark_points ]
# 		1.268E-04   and   4.871E+04 	[ momenta ]
# >> Step size and gradient norm:
# 		2.899E-05   and   6.646E+05 	[ landmark_points ]
# 		6.341E-05   and   4.871E+04 	[ momenta ]
# ------------------------------------- Iteration: 39 -------------------------------------
# >> Log-likelihood = -1.805E+08 	 [ attachment = -1.800E+08 ; regularity = -4.605E+05 ]
# >> Step size and gradient norm:
# 		4.348E-05   and   6.140E+05 	[ landmark_points ]
# 		9.512E-05   and   5.094E+04 	[ momenta ]
# ------------------------------------- Iteration: 40 -------------------------------------
# >> Log-likelihood = -1.804E+08 	 [ attachment = -1.800E+08 ; regularity = -4.619E+05 ]
# >> Step size and gradient norm:
# 		4.348E-05   and   8.312E+05 	[ landmark_points ]
# 		4.756E-05   and   5.591E+04 	[ momenta ]
# Tolerance threshold met. Stopping the optimization process.
# >> Estimation took: 22 minutes and 54 seconds

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# print available saved status keys
print(iteration_status_dictionaries[-1].keys())
# print(iteration_status_dictionaries[-1]['gradient'].keys())

y = [it_data['current_log_likelihood'] for it_data in iteration_status_dictionaries]
#print(len(y))
x = np.arange(1, estimator_options['max_iterations']+1)
x = np.arange(1, len(y)+1)

fig = plt.figure()

# plot log-likelihood
plt.plot(x, [it_data['current_log_likelihood'] for it_data in iteration_status_dictionaries], label='log_likelihood')
# plt.plot(x, [it_data['current_attachment'] for it_data in iteration_status_dictionaries], label='attachment')
# plt.plot(x, [it_data['current_regularity'] for it_data in iteration_status_dictionaries], label='regularity')

plt.xticks(x)

plt.style.use('default')
plt.legend()
plt.show()
# Out:
# dict_keys(['current_iteration', 'current_log_likelihood', 'current_attachment', 'current_regularity', 'gradient'])

# %%
####
#### LOAD RELEVANT INPUT DATA
####

import deformetrica as dfca

path_to_template_ini = template_specifications['aorta']['filename']
template_points__ini, dimension, template_connectivity__ini = dfca.io.DeformableObjectReader.read_file(path_to_template_ini, extract_connectivity=True)

####
#### LOAD RELEVANT OUTPUT DATA
####

fixed_effects = model.fixed_effects

template_points__est = fixed_effects['template_data']['landmark_points']
control_points__est = fixed_effects['control_points']
momenta__est = fixed_effects['momenta']

####
#### PLOT INITIAL AND ESTIMATED TEMPLATES
####

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib import cm
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

figsize = 5
f = plt.figure(figsize=(3*figsize, 1*figsize))
gs = gridspec.GridSpec(1, 3)

# Initial template
ax = plt.subplot(gs[0, 0])
p = template_points__ini
c = template_connectivity__ini
ax.plot([p[c[:,0]][:,0], p[c[:,1]][:,0]], 
        [p[c[:,0]][:,1], p[c[:,1]][:,1]], 'k', linewidth=4)
ax.set_title('Initial template')

# Estimated template
ax = plt.subplot(gs[0, 1])
p = template_points__est
ax.plot([p[c[:,0]][:,0], p[c[:,1]][:,0]], [p[c[:,0]][:,1], p[c[:,1]][:,1]], 'k', linewidth=4)
ax.set_title('Estimated template')

# Estimated template and momenta
ax = plt.subplot(gs[0, 2])
x = control_points__est
ax.plot([p[c[:,0]][:,0], p[c[:,1]][:,0]], [p[c[:,0]][:,1], p[c[:,1]][:,1]], 'k', linewidth=4)
cmap = cm.get_cmap('tab10')
for i, m in enumerate(momenta__est):
    color = cmap(i % 10)[:3]
    ax.quiver(x[:,0], x[:,1], m[:,0], m[:,1], color=color, width=0.01, scale=75)
ax.set_title('Estimated Template and Momenta')

####
#### PLOT RAW VERSUS RECONSTRUCTED DATA
####

import torch 

figsize = 3
f = plt.figure(figsize=(5*figsize, 1*figsize))
gs = gridspec.GridSpec(1, 5)

for i, momentum__est in enumerate(momenta__est): 
    ax = plt.subplot(gs[0, i])
    color = cmap(i % 10)[:3]
  
    # Load and plot raw target. 
    path_to_target__raw = dataset_specifications['dataset_filenames'][i][0]['aorta']
    target_id = dataset_specifications['subject_ids'][i]
    target_points__raw, _, target_connectivity__raw = dfca.io.DeformableObjectReader.read_file(path_to_target__raw, extract_connectivity=True)

    p = target_points__raw
    c = target_connectivity__raw
    ax.plot([p[c[:,0]][:,0], p[c[:,1]][:,0]], [p[c[:,0]][:,1], p[c[:,1]][:,1]], 'k', linewidth=2)
    ax.set_title(target_id)
  
    # Compute and plot the reconstruction of the target. 
    model.exponential.set_initial_momenta(torch.from_numpy(momentum__est).to(torch.float32))
    model.exponential.update()
    target_points__rec = model.exponential.get_template_points()['landmark_points'].detach().cpu().numpy()
  
    p = target_points__rec
    c = template_connectivity__ini
    ax.plot([p[c[:,0]][:,0], p[c[:,1]][:,0]], [p[c[:,0]][:,1], p[c[:,1]][:,1]], color=color, linewidth=2)

plt.style.use('default')
plt.show()
# Out:
# /tmp/ipykernel_635937/686005836.py:52: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('tab10')
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 69
#      66 gs = gridspec.GridSpec(1, 5)
#      68 for i, momentum__est in enumerate(momenta__est):
# ---> 69     ax = plt.subplot(gs[0, i])
#      70     color = cmap(i % 10)[:3]
#      72     # Load and plot raw target.
#
# File /opt/anaconda3/envs/deformetrica/lib/python3.8/site-packages/matplotlib/gridspec.py:258, in GridSpecBase.__getitem__(self, key)
#     255     except ValueError as err:
#     256         raise ValueError("Unrecognized subplot spec") from err
#     257     num1, num2 = np.ravel_multi_index(
# --> 258         [_normalize(k1, nrows, 0), _normalize(k2, ncols, 1)],
#     259         (nrows, ncols))
#     260 else:  # Single key
#     261     num1, num2 = _normalize(key, nrows * ncols, None)
#
# File /opt/anaconda3/envs/deformetrica/lib/python3.8/site-packages/matplotlib/gridspec.py:246, in GridSpecBase.__getitem__.<locals>._normalize(key, size, axis)
#     244     return key, key
#     245 elif axis is not None:
# --> 246     raise IndexError(f"index {orig_key} is out of bounds for "
#     247                      f"axis {axis} with size {size}")
#     248 else:  # flat index
#     249     raise IndexError(f"index {orig_key} is out of bounds for "
#     250                      f"GridSpec with size {size}")
#
# IndexError: index 5 is out of bounds for axis 1 with size 5

# %%
### CHOOSE WHICH ORGAN TO PLOT
organ = 'hippo'
organ = 'amygdala'

path_to_template__ini = template_specifications[organ]['filename']
template_points__ini, dimension, template_connectivity__ini = dfca.io.DeformableObjectReader.read_file(path_to_template__ini, extract_connectivity=True)

####
#### LOAD RELEVANT OUTPUT DATA
####

fixed_effects = model.fixed_effects

template_points__est = fixed_effects['template_data']['landmark_points']
control_points__est = fixed_effects['control_points']
momenta__est = fixed_effects['momenta']

####
#### PLOT INITIAL AND ESTIMATED TEMPLATES
####

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib import cm
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

figsize = 5
f = plt.figure(figsize=(3*figsize, 1*figsize))
gs = gridspec.GridSpec(1, 3)

# Initial template
ax = plt.subplot(gs[0, 0], projection='3d')
p = template_points__ini
c = template_connectivity__ini
for i in range(0, len(p[c[:,0]][:,0])):
    ax.plot3D(
        [p[c[:,0]][:,0][i], p[c[:,1]][:,0][i]],
        [p[c[:,0]][:,1][i], p[c[:,1]][:,1][i]],
        [p[c[:,0]][:,2][i], p[c[:,1]][:,2][i]],
        color='k', linewidth=1)
ax.set_title('Initial template')
ax.view_init(120, -90)

# Estimated template
ax = plt.subplot(gs[0, 1], projection='3d')
p = template_points__est
for i in range(0, len(p[c[:,0]][:,0])):
    ax.plot3D(
        [p[c[:,0]][:,0][i], p[c[:,1]][:,0][i]],
        [p[c[:,0]][:,1][i], p[c[:,1]][:,1][i]],
        [p[c[:,0]][:,2][i], p[c[:,1]][:,2][i]],
        color='k', linewidth=1)
ax.set_title('Estimated template')
ax.view_init(120, -90)

# Estimated template and momenta
ax = plt.subplot(gs[0, 2], projection='3d')
x = control_points__est
for i in range(0, len(p[c[:,0]][:,0])):
    ax.plot3D(
        [p[c[:,0]][:,0][i], p[c[:,1]][:,0][i]],
        [p[c[:,0]][:,1][i], p[c[:,1]][:,1][i]],
        [p[c[:,0]][:,2][i], p[c[:,1]][:,2][i]],
        color='k', linewidth=1) 
    
cmap = cm.get_cmap('tab10')
for i, m in enumerate(momenta__est):
    color = cmap(i % 10)[:3]
    ax.quiver3D(x[:,0], x[:,1], x[:,2], 
                m[:,0], m[:,1], m[:,2], 
                #m[0], m[1], m[2], 
                color=color, 
                length=20,
#                 width=0.01, 
#                 scale=75
               )
ax.set_title('Estimated template and momenta')
ax.view_init(120, -90)

plt.style.use('default')
plt.show()

####
#### PLOT RAW VERSUS RECONSTRUCTED DATA
####

import torch 

figsize = 3
f = plt.figure(figsize=(5*figsize, 1*figsize))
gs = gridspec.GridSpec(1, 5)

for i, momentum__est in enumerate(momenta__est): 
    ax = plt.subplot(gs[0, i], projection='3d')
    color = cmap(i % 10)[:3]
  
    # Load and plot raw target. 
    path_to_target__raw = dataset_specifications['dataset_filenames'][i][0][organ]
    print(path_to_target__raw)
    target_id = dataset_specifications['subject_ids'][i]
    target_points__raw, _, target_connectivity__raw = dfca.io.DeformableObjectReader.read_file(path_to_target__raw, extract_connectivity=True)

    p = target_points__raw
    c = target_connectivity__raw
    for i in range(0, len(p[c[:,0]][:,0])):
        ax.plot3D(
            [p[c[:,0]][:,0][i], p[c[:,1]][:,0][i]],
            [p[c[:,0]][:,1][i], p[c[:,1]][:,1][i]],
            [p[c[:,0]][:,2][i], p[c[:,1]][:,2][i]],
            color='k', linewidth=1)
    #ax.plot([p[c[:,0]][:,0], p[c[:,1]][:,0]], [p[c[:,0]][:,1], p[c[:,1]][:,1]], 'k', linewidth=2)
    ax.set_title(target_id)
  
    # Compute and plot the reconstruction of the target. 
    model.exponential.set_initial_momenta(torch.from_numpy(momentum__est).to(torch.float32))
    model.exponential.update()
    target_points__rec = model.exponential.get_template_points()['landmark_points'].detach().cpu().numpy()
  
    p = target_points__rec
    c = template_connectivity__ini
    #ax.plot([p[c[:,0]][:,0], p[c[:,1]][:,0]], [p[c[:,0]][:,1], p[c[:,1]][:,1]], color=color, linewidth=2)
    for i in range(0, len(p[c[:,0]][:,0])):
        ax.plot3D(
            [p[c[:,0]][:,0][i], p[c[:,1]][:,0][i]],
            [p[c[:,0]][:,1][i], p[c[:,1]][:,1][i]],
            [p[c[:,0]][:,2][i], p[c[:,1]][:,2][i]],
            color=color, linewidth=1)

plt.style.use('default')
plt.show()

# %%
import os
import deformetrica as dfca

#organ = 'hippo'
organ = 'amygdala'

### EDIT THESE PATHS #####################
data_path = '/u/i/sm2894/Documents/FYP/'
data_base = os.path.join(data_path, 'Data/clinical sm/')

output_directory = './brain_' + organ + '_output/' #directory where the outputs will be saved
########################################

iteration_status_dictionaries = []

def estimator_callback(status_dict):
    iteration_status_dictionaries.append(status_dict)
    return True

# instantiate a Deformetrica object
deformetrica = dfca.Deformetrica(output_dir=output_directory, verbosity='INFO')

dataset_specifications = {
    'dataset_filenames': [
        [{organ: os.path.join(data_base, organ + '1.vtk')}],
        [{organ: os.path.join(data_base, organ + '2.vtk')}],
        [{organ: os.path.join(data_base, organ + '3.vtk')}],
        [{organ: os.path.join(data_base, organ + '4.vtk')}]
    ],
    'subject_ids': ['subject1', 'subject2', 'subject3', 'subject4'],
}
if organ == "hippo":
    template_name = 'hippo_prototype.vtk'
elif organ == "amygdala":
    template_name = 'amyg_prototype.vtk'
    
template_specifications = {
    organ: {'deformable_object_type': 'SurfaceMesh',
              'kernel_type': 'torch', 'kernel_width': 25.0, #Vary this
              'noise_std': 10.0, #Vary this
              'filename': os.path.join(data_base, template_name),
              'attachment_type': 'Current',
              #'kernel_device' : 'cpu'
                },   
}

#estimator_options={'optimization_method_type': 'GradientAscent', 'initial_step_size': 1.,
#                   'max_iterations': 100, 'max_line_search_iterations': 20, 'callback': estimator_callback}

estimator_options={'optimization_method_type': 'GradientAscent', 
                   'initial_step_size': 0.01, #
                   'max_iterations': 500, #
                   'max_line_search_iterations': 10, 
                   'convergence_tolerance': 1e-4, #
                   'freeze_template': 'Off',
                   'number_of_processes': 4,
                   'callback': estimator_callback}

# deformation-parameters 
model_options={'deformation_kernel_type': 'torch', 
               'deformation_kernel_width': 25.0, #Vary this
               'dtype': 'float32'}


model = deformetrica.estimate_deterministic_atlas(template_specifications, dataset_specifications,
                                                estimator_options=estimator_options,
                                                model_options=model_options)

# %%
### CHOOSE WHICH ORGAN TO PLOT


path_to_template__ini = template_specifications[organ]['filename']
template_points__ini, dimension, template_connectivity__ini = dfca.io.DeformableObjectReader.read_file(path_to_template__ini, extract_connectivity=True)

####
#### LOAD RELEVANT OUTPUT DATA
####

fixed_effects = model.fixed_effects

template_points__est = fixed_effects['template_data']['landmark_points']
control_points__est = fixed_effects['control_points']
momenta__est = fixed_effects['momenta']

####
#### PLOT INITIAL AND ESTIMATED TEMPLATES
####

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib import cm
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

figsize = 5
f = plt.figure(figsize=(3*figsize, 1*figsize))
gs = gridspec.GridSpec(1, 3)

# Initial template
ax = plt.subplot(gs[0, 0], projection='3d')
p = template_points__ini
c = template_connectivity__ini
for i in range(0, len(p[c[:,0]][:,0])):
    ax.plot3D(
        [p[c[:,0]][:,0][i], p[c[:,1]][:,0][i]],
        [p[c[:,0]][:,1][i], p[c[:,1]][:,1][i]],
        [p[c[:,0]][:,2][i], p[c[:,1]][:,2][i]],
        color='k', linewidth=1)
ax.set_title('Initial template')
ax.view_init(120, -90)

# Estimated template
ax = plt.subplot(gs[0, 1], projection='3d')
p = template_points__est
for i in range(0, len(p[c[:,0]][:,0])):
    ax.plot3D(
        [p[c[:,0]][:,0][i], p[c[:,1]][:,0][i]],
        [p[c[:,0]][:,1][i], p[c[:,1]][:,1][i]],
        [p[c[:,0]][:,2][i], p[c[:,1]][:,2][i]],
        color='k', linewidth=1)
ax.set_title('Estimated template')
ax.view_init(120, -90)

# Estimated template and momenta
ax = plt.subplot(gs[0, 2], projection='3d')
x = control_points__est
for i in range(0, len(p[c[:,0]][:,0])):
    ax.plot3D(
        [p[c[:,0]][:,0][i], p[c[:,1]][:,0][i]],
        [p[c[:,0]][:,1][i], p[c[:,1]][:,1][i]],
        [p[c[:,0]][:,2][i], p[c[:,1]][:,2][i]],
        color='k', linewidth=1) 
    
cmap = cm.get_cmap('tab10')
for i, m in enumerate(momenta__est):
    color = cmap(i % 10)[:3]
    ax.quiver3D(x[:,0], x[:,1], x[:,2], 
                m[:,0], m[:,1], m[:,2], 
                #m[0], m[1], m[2], 
                color=color, 
                length=20,
#                 width=0.01, 
#                 scale=75
               )
ax.set_title('Estimated template and momenta')
ax.view_init(120, -90)

plt.style.use('default')
plt.show()

####
#### PLOT RAW VERSUS RECONSTRUCTED DATA
####

import torch 

figsize = 3
f = plt.figure(figsize=(5*figsize, 1*figsize))
gs = gridspec.GridSpec(1, 5)

for i, momentum__est in enumerate(momenta__est): 
    ax = plt.subplot(gs[0, i], projection='3d')
    color = cmap(i % 10)[:3]
  
    # Load and plot raw target. 
    path_to_target__raw = dataset_specifications['dataset_filenames'][i][0][organ]
    print(path_to_target__raw)
    target_id = dataset_specifications['subject_ids'][i]
    target_points__raw, _, target_connectivity__raw = dfca.io.DeformableObjectReader.read_file(path_to_target__raw, extract_connectivity=True)

    p = target_points__raw
    c = target_connectivity__raw
    for i in range(0, len(p[c[:,0]][:,0])):
        ax.plot3D(
            [p[c[:,0]][:,0][i], p[c[:,1]][:,0][i]],
            [p[c[:,0]][:,1][i], p[c[:,1]][:,1][i]],
            [p[c[:,0]][:,2][i], p[c[:,1]][:,2][i]],
            color='k', linewidth=1)
    #ax.plot([p[c[:,0]][:,0], p[c[:,1]][:,0]], [p[c[:,0]][:,1], p[c[:,1]][:,1]], 'k', linewidth=2)
    ax.set_title(target_id)
  
    # Compute and plot the reconstruction of the target. 
    model.exponential.set_initial_momenta(torch.from_numpy(momentum__est).to(torch.float32))
    model.exponential.update()
    target_points__rec = model.exponential.get_template_points()['landmark_points'].detach().cpu().numpy()
  
    p = target_points__rec
    c = template_connectivity__ini
    #ax.plot([p[c[:,0]][:,0], p[c[:,1]][:,0]], [p[c[:,0]][:,1], p[c[:,1]][:,1]], color=color, linewidth=2)
    for i in range(0, len(p[c[:,0]][:,0])):
        ax.plot3D(
            [p[c[:,0]][:,0][i], p[c[:,1]][:,0][i]],
            [p[c[:,0]][:,1][i], p[c[:,1]][:,1][i]],
            [p[c[:,0]][:,2][i], p[c[:,1]][:,2][i]],
            color=color, linewidth=1)

plt.style.use('default')
plt.show()
